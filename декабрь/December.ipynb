# %%
import pandas as pd
decmbr_ad_data = pd.read_csv('AnalysisTaskAd_20230328-20230328_cCBKCUO7JeHt3FkozvqeWbga.csv')

# %%
display(decmbr_ad_data)
# Out:
#      Time  Store name Product name              PID           robotMAC
# 0   17:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70  \
# 1   16:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 2   15:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 3   14:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 4   13:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 5   12:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 6   11:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 7   10:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 8    9:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 9    8:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 10   7:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 11   6:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# ...

# %%
decmbr_ad_data['Activated on'].drop
display(decmbr_ad_data)
# Out:
#      Time  Store name Product name              PID           robotMAC
# 0   17:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70  \
# 1   16:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 2   15:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 3   14:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 4   13:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 5   12:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 6   11:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 7   10:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 8    9:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 9    8:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 10   7:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# 11   6:00  Динозаврия     kettybot  PNT102213716159  20:50:E7:23:96:70
# ...
