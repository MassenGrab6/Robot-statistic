# %%
import numpy as np
import pandas as pd
mrt_run_data  = pd.read_csv('AnalysisRun_20230301-20230331_Q8qmsBk4zBZNdarLs7q1SvfN.csv')

# %%
mrt_run_data.drop(['PID','unbound','Start running time'], axis= 1)
# Out:
#            Time Product name           robotMAC               Store
# 0    2023-03-31     bellabot  20:50:E7:23:71:74  Ресторан ГрильХаус  \
# 1    2023-03-31     bellabot  20:50:E7:02:FD:68            Perchini
# 2    2023-03-31     bellabot  20:50:E7:23:3D:AA         Soft-servis
# 3    2023-03-31     bellabot  20:50:E7:02:C0:F2         Soft-servis
# 4    2023-03-31     bellabot  D4:12:43:B0:D5:68   Gastreet_panorama
# ..          ...          ...                ...                 ...
# 951  2023-03-01     bellabot  20:50:E7:02:FD:68            Perchini
# 952  2023-03-01     bellabot  20:50:E7:23:71:74  Ресторан ГрильХаус
# 953  2023-03-01     bellabot  20:50:E7:23:79:E8      Flagman office
# 954  2023-03-01     bellabot  20:50:E7:02:EB:56              Компот
# 955  2023-03-01     bellabot  20:50:E7:02:24:2A            Parmesan
#
#      Operating time (h)  Running mileage (km)  Number of tasks
# 0                  0.58                  0.61               42
# ...

# %%
sum_mrt_run_data = mrt_run_data.copy
mean_mrt_run_data = mrt_run_data.copy

sum_mrt_run_data  = sum_mrt_run_data.groupby()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 4
#       1 sum_mrt_run_data = mrt_run_data.copy
#       2 mean_mrt_run_data = mrt_run_data.copy
# ----> 4 sum_mrt_run_data  = sum_mrt_run_data.groupby('Operating time(h)').sum()
#
# AttributeError: 'function' object has no attribute 'groupby'
