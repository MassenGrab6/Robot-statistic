# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
mart_run = pd.read_csv('AnalysisRun_20230301-20230331_Q8qmsBk4zBZNdarLs7q1SvfN.csv')
mart_run =mart_run.drop(['PID', 'robotMAC','Start running time','unbound','Time'],axis = 1)
mart_run.columns
# Out:
# Index(['Product name', 'Store', 'Operating time (h)', 'Running mileage (km)',
#        'Number of tasks'],
#       dtype='object')

# %%
mart_run = mart_run.groupby(['Store','Product name']).sum()

display(mart_run)
# Out:
#                                     Operating time (h)  Running mileage (km)  \
# Store                 Product name
# Baltiya Hotel         kettybot                  262.83                  1.65
# Chajhana hariba       bellabot                    4.45                  9.17
# Firemakers            bellabot                   64.03                 70.15
# Flagman office        bellabot                    8.68                  8.57
# Fun Jump              bellabot                   52.21                 55.49
# Fun Jump Kazan        bellabot                   36.12                 25.74
# Gastreet_panorama     bellabot                   80.69                 72.93
#                       pudubot                     0.71                  0.49
# Jango Park            bellabot                   16.62                 13.78
# Neo                   kettybot                   23.18                 14.69
# Parmesan              bellabot                  127.93                 87.35
# ...

# %%
mart_run2 = pd.read_csv('AnalysisRun_20230301-20230331_Q8qmsBk4zBZNdarLs7q1SvfN.csv')
mart_run2 = mart_run2.drop(['Time','PID','robotMAC','Start running time', 'unbound'],axis=1)
mart_run2 = mart_run2.groupby(['Store']).sum()
mart_run2.head()
# Out:
# C:\Users\Massengrab\AppData\Local\Temp\ipykernel_7428\2766488511.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mart_run2 = mart_run2.groupby(['Store']).sum()
#                  Operating time (h)  Running mileage (km)  Number of tasks
# Store
# Baltiya Hotel                262.83                  1.65              176
# Chajhana hariba                4.45                  9.17               71
# Firemakers                    64.03                 70.15             4718
# Flagman office                 8.68                  8.57              469
# Fun Jump                      52.21                 55.49             1927

# %%
mart_run2.to_excel('Mart_run.xlsx')

# %%
sns.barplot(data = mart_run2, x ='Store', y = 'Operating time (h)')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Massengrab\Desktop\job_project\Robot-statistic\март\Marth_data.ipynb Ячейка 6 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Massengrab/Desktop/job_project/Robot-statistic/%D0%BC%D0%B0%D1%80%D1%82/Marth_data.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> sns.barplot(data = mart_run2, x ='Store ', y = 'Operating time (h)')
#
# File c:\Users\Massengrab\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
# ...
