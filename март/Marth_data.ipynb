# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
mart_run = pd.read_csv('AnalysisRun_20230301-20230331_Q8qmsBk4zBZNdarLs7q1SvfN.csv')
mart_run =mart_run.drop(['PID', 'robotMAC','Start running time','unbound','Time'],axis = 1)
mart_run.columns
# Out:
# Index(['Product name', 'Store', 'Operating time (h)', 'Running mileage (km)',
#        'Number of tasks'],
#       dtype='object')

# %%
mart_run = mart_run.groupby(['Store','Product name']).sum()

display(mart_run)
# Out:
#                                     Operating time (h)  Running mileage (km)  \
# Store                 Product name
# Baltiya Hotel         kettybot                  262.83                  1.65
# Chajhana hariba       bellabot                    4.45                  9.17
# Firemakers            bellabot                   64.03                 70.15
# Flagman office        bellabot                    8.68                  8.57
# Fun Jump              bellabot                   52.21                 55.49
# Fun Jump Kazan        bellabot                   36.12                 25.74
# Gastreet_panorama     bellabot                   80.69                 72.93
#                       pudubot                     0.71                  0.49
# Jango Park            bellabot                   16.62                 13.78
# Neo                   kettybot                   23.18                 14.69
# Parmesan              bellabot                  127.93                 87.35
#                       kettybot                   20.03                 14.42
# Perchini              bellabot                   33.36                 34.32
# Sber Univercity       bellabot                  144.22                 16.30
# Soft-Stend            bellabot                  111.65                 82.60
# Soft-servis           bellabot                  179.54                186.94
# Velich                bellabot                    2.62                  2.25
# АРТ-Премиум           bellabot                    7.08                  1.72
# Деревенское Молочко   kettybot                    0.02                  0.01
# Динозаврия            bellabot                   32.11                 25.04
#                       kettybot                    0.25                  0.04
# Компот                bellabot                   52.06                 39.75
# Ресторан ГрильХаус    bellabot                   19.41                 17.73
# Санаторий Заполярье   pudubot                    23.14                  2.65
# Фанджамп Екатеринбург bellabot                   53.66                 64.15
# Чайхана PLOV          bellabot                    2.27                  2.28
#
#                                     Number of tasks
# Store                 Product name
# Baltiya Hotel         kettybot                  176
# Chajhana hariba       bellabot                   71
# Firemakers            bellabot                 4718
# Flagman office        bellabot                  469
# Fun Jump              bellabot                 1927
# Fun Jump Kazan        bellabot                 1164
# Gastreet_panorama     bellabot                 2138
#                       pudubot                    28
# Jango Park            bellabot                  613
# Neo                   kettybot                 1834
# Parmesan              bellabot                 5870
#                       kettybot                 1166
# Perchini              bellabot                 1740
# Sber Univercity       bellabot                  880
# Soft-Stend            bellabot                 5297
# Soft-servis           bellabot                 6267
# Velich                bellabot                  151
# АРТ-Премиум           bellabot                  226
# Деревенское Молочко   kettybot                    2
# Динозаврия            bellabot                  985
#                       kettybot                   31
# Компот                bellabot                 3981
# Ресторан ГрильХаус    bellabot                 1097
# Санаторий Заполярье   pudubot                     3
# Фанджамп Екатеринбург bellabot                 1296
# Чайхана PLOV          bellabot                   88

# %%
mart_run.to_excel("mart_run.xlsx",sheet_name="MartRun", index = False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Massengrab\Desktop\job_project\Robot-statistic\март\Marth_data.ipynb Ячейка 4 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Massengrab/Desktop/job_project/Robot-statistic/%D0%BC%D0%B0%D1%80%D1%82/Marth_data.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> mart_run.to_excel("mart_run.xlsx",sheet_name="MartRun", index = False)
#
# File c:\Users\Massengrab\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\Massengrab\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\Massengrab\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:2373, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2360 from pandas.io.formats.excel import ExcelFormatter
#    2362 formatter = ExcelFormatter(
#    2363     df,
#    2364     na_rep=na_rep,
#    (...)
#    2371     inf_rep=inf_rep,
#    2372 )
# -> 2373 formatter.write(
#    2374     excel_writer,
#    2375     sheet_name=sheet_name,
#    2376     startrow=startrow,
#    2377     startcol=startcol,
#    2378     freeze_panes=freeze_panes,
#    2379     engine=engine,
#    2380     storage_options=storage_options,
#    2381 )
#
# File c:\Users\Massengrab\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\formats\excel.py:911, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     907     need_save = False
#     908 else:
#     909     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     910     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 911     writer = ExcelWriter(  # type: ignore[abstract]
#     912         writer, engine=engine, storage_options=storage_options
#     913     )
#     914     need_save = True
#     916 try:
#
# File c:\Users\Massengrab\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\excel\_openpyxl.py:56, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      43 def __init__(
#      44     self,
#      45     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#      54 ) -> None:
#      55     # Use the openpyxl module as the Excel writer.
# ---> 56     from openpyxl.workbook import Workbook
#      58     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      60     super().__init__(
#      61         path,
#      62         mode=mode,
#    (...)
#      65         engine_kwargs=engine_kwargs,
#      66     )
#
# ModuleNotFoundError: No module named 'openpyxl'
